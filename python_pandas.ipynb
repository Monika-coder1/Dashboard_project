# %% [markdown]
# <a href="https://colab.research.google.com/github/Monika-coder1/Dashboard_project/blob/main/python_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
n1=pd.Series([11,22,33,44,55,66,77,88,99],index=[0,1,2,3,4,5,6,7,8])
print(n1)
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# 5    66
# 6    77
# 7    88
# 8    99
# dtype: int64

# %%
len(n1)
# Out:
# 9

# %%
df={1011:'Mohan',1012:'shyam',1013:'"Madhav',1015:'Kisan'}
df=pd.Series(df)
df
# Out:
# 1011      Mohan
# 1012      shyam
# 1013    "Madhav
# 1015      Kisan
# dtype: object

# %%
n1=pd.Series([11,22,33,44,55,66,77,88,99],index=[0,1,2,3,4,5,6,7,8],dtype="float",name="mydata")
n1
# Out:
# 0    11.0
# 1    22.0
# 2    33.0
# 3    44.0
# 4    55.0
# 5    66.0
# 6    77.0
# 7    88.0
# 8    99.0
# Name: mydata, dtype: float64

# %%
n1=pd.Series([11,22,33,44,55,66,77,88,99],index=range(0,9))
n1
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# 5    66
# 6    77
# 7    88
# 8    99
# dtype: int64

# %%
n1
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# 5    66
# 6    77
# 7    88
# 8    99
# dtype: int64

# %%
n1[1]
# Out:
# np.int64(22)

# %%
n1[0]
# Out:
# np.int64(11)

# %%
n1[:5]
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64

# %%
n1[1]=58

# %%
n1
# Out:
# 0    11
# 1    58
# 2    33
# 3    44
# 4    55
# 5    66
# 6    77
# 7    88
# 8    99
# dtype: int64

# %%
df=n1.drop(index=5)
df
# Out:
# 0    11
# 1    58
# 2    33
# 3    44
# 4    55
# 6    77
# 7    88
# 8    99
# dtype: int64

# %%
df=n1.drop(index=[2,4,8])
df
# Out:
# 0    11
# 1    58
# 3    44
# 5    66
# 6    77
# 7    88
# dtype: int64

# %%
df[df>30]
# Out:
# 1    58
# 3    44
# 5    66
# 6    77
# 7    88
# dtype: int64

# %%
df[df<30]
# Out:
# 0    11
# dtype: int64

# %%
#dictionay
import pandas as pd
d={'Name':'Hardik','Iplteam':'MI','runs':1500}
df=pd.Series(d,name="mydata")
df
# Out:
# Name       Hardik
# Iplteam        MI
# runs         1500
# Name: mydata, dtype: object

# %%
#head and Tail function in series
import pandas as pd
arr=pd.Series([10,15,18,22,55,77,42,49,97])
arr.head()
arr.head(3)
# Out:
# 0    10
# 1    15
# 2    18
# dtype: int64

# %%
import pandas as pd
arr=pd.Series([10,15,18,22,55,77,42,49,97])
arr.tail()
# Out:
# 4    55
# 5    77
# 6    42
# 7    49
# 8    97
# dtype: int64

# %%
#dataFrame
emp_data = pd.DataFrame({'emp_id':[1011,1012,1013,1014],'name':['mohan','shyam','kisan','ram']})
emp_data
# Out:
#    emp_id   name
# 0    1011  mohan
# 1    1012  shyam
# 2    1013  kisan
# 3    1014    ram

# %%
emp_data['dept'] = ['hr','developer','hr','admin']
emp_data
# Out:
#    emp_id   name    sal       dept
# 0    1011  mohan  22000         hr
# 1    1012  shyam  25000  developer
# 2    1013  kisan  32000         hr
# 3    1014    ram  45200      admin

# %%
emp_data['sal']=[22000,25000,32000,45200]
emp_data
# Out:
#    emp_id   name    sal       dept
# 0    1011  mohan  22000         hr
# 1    1012  shyam  25000  developer
# 2    1013  kisan  32000         hr
# 3    1014    ram  45200      admin

# %%
emp_data[['emp_id','sal']]
emp_data
# Out:
#    emp_id   name    sal       dept
# 0    1011  mohan  22000         hr
# 1    1012  shyam  25000  developer
# 2    1013  kisan  32000         hr
# 3    1014    ram  45200      admin

# %%
emp_data
# Out:
#    emp_id   name    sal       dept
# 0    1011  mohan  22000         hr
# 1    1012  shyam  25000  developer
# 2    1013  kisan  32000         hr
# 3    1014    ram  45200      admin

# %%
emp_data.loc[2]
# Out:
# emp_id     1013
# name      kisan
# sal       32000
# dept         hr
# Name: 2, dtype: object

# %%
emp_data.loc[[1,3]]
# Out:
#    emp_id   name    sal       dept
# 1    1012  shyam  25000  developer
# 3    1014    ram  45200      admin

# %%
emp_data
# Out:
#    emp_id   name    sal       dept
# 0    1011  mohan  22000         hr
# 1    1012  shyam  25000  developer
# 2    1013  kisan  32000         hr
# 3    1014    ram  45200      admin

# %%
#change some data
emp_data.loc[4]=[1015,'gopal',62000,'IT']
emp_data
# Out:
#    emp_id   name    sal       dept
# 0    1011  mohan  22000         hr
# 1    1012  shyam  25000  developer
# 2    1013  kisan  32000         hr
# 3    1014    ram  45200      admin
# 4    1015  gopal  62000         IT

# %%
emp_data[emp_data['sal']>30000]
# Out:
#    emp_id   name    sal   dept
# 2    1013  kisan  32000     hr
# 3    1014    ram  45200  admin
# 4    1015  gopal  62000     IT

# %%
emp_data[emp_data['sal']<30000]
# Out:
#    emp_id   name    sal       dept
# 0    1011  mohan  22000         hr
# 1    1012  shyam  25000  developer

# %%
#sal >30k
#dept== hr
emp_data.query("dept=='hr'" or sal >30000)
# Out:
#    emp_id   name    sal dept
# 0    1011  mohan  22000   hr
# 2    1013  kisan  32000   hr

# %%
import pandas as pd
df=pd.read_csv("/content/kc_house_data.csv")

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
#head()
#tail()
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1230000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.tail(10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1010000.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21603         2270      5536     2.0           0     0  ...      8
# 21604         1490      1126     3.0           0     0  ...      8
# ...

# %%
#df.shape=(no. of rows , no. of columns)
df.shape
# Out:
# (21613, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# df.iloc[start_row : End_rowno : Step , Start_columnno : End_columnno : step ]
df.iloc[200:251:10,0:6:2]
# Out:
#              id     price  bathrooms
# 200  3542300060  210000.0       1.00
# 210  2310030510  320000.0       2.25
# 220  5611500140  686000.0       2.50
# 230  8096000060  655000.0       1.75
# 240  3584000310  225000.0       1.75
# 250  3832710960  260000.0       2.00

# %%
df.iloc[50:,5:]
# Out:
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 50            1190      9199     1.0           0     0          3      7
# 51            3150      9134     1.0           0     0          4      8
# 52            1410      4080     1.0           0     0          4      7
# 53            1980      8550     1.0           0     0          3      7
# 54            2730      6000     1.5           0     0          3      8
# ...            ...       ...     ...         ...   ...        ...    ...
# 21608         1530      1131     3.0           0     0          3      8
# 21609         2310      5813     2.0           0     0          3      8
# 21610         1020      1350     2.0           0     0          3      7
# 21611         1600      2388     2.0           0     0          3      8
# 21612         1020      1076     2.0           0     0          3      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
df.iloc[200:149:-1,::-1]
# Out:
#      sqft_lot15  sqft_living15     long      lat  zipcode  yr_renovated  \
# 200        9514           1300 -122.184  47.5093    98056             0
# 199       50965           1560 -121.994  47.4058    98038             0
# 198       67268           2330 -121.911  47.5385    98024             0
# 197        2385           1750 -122.372  47.5488    98126             0
# 196        6480           1500 -122.312  47.5511    98108             0
# 195        5001           2550 -122.347  47.2779    98023             0
# 194       10228           1570 -122.300  47.7481    98155             0
# 193        7818           1900 -122.336  47.7606    98133             0
# 192       10083           2680 -122.219  47.5505    98040             0
# 191        7980           1230 -122.184  47.4616    98058             0
# 190        8400           1540 -122.191  47.7260    98034             0
# 189        9340           2230 -122.153  47.6647    98052             0
# ...

# %%
df.iloc[200:189:-1,-4:]
# Out:
#          lat     long  sqft_living15  sqft_lot15
# 200  47.5093 -122.184           1300        9514
# 199  47.4058 -121.994           1560       50965
# 198  47.5385 -121.911           2330       67268
# 197  47.5488 -122.372           1750        2385
# 196  47.5511 -122.312           1500        6480
# 195  47.2779 -122.347           2550        5001
# 194  47.7481 -122.300           1570       10228
# 193  47.7606 -122.336           1900        7818
# 192  47.5505 -122.219           2680       10083
# 191  47.4616 -122.184           1230        7980
# 190  47.7260 -122.191           1540        8400

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df=df.drop(['id','date'],axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
#row no-190,134,56,20 ,45
#cloums - price,bedrooms,floors,bathrooms
#loc
df.loc[[190,134,56,20 ,45]][['price','bedrooms','floors','bathrooms']]
# Out:
#         price  bedrooms  floors  bathrooms
# 190  305000.0         3     1.0       1.75
# 134  675000.0         4     3.0       3.50
# 56   292500.0         4     2.0       2.50
# 20   385000.0         4     1.0       1.75
# 45   488000.0         3     2.0       2.50

# %%
df.query("bedrooms>=3 and bathrooms>=2 and floors<=2")
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1       538000.0         3       2.25         2570      7242     2.0
# 3       604000.0         4       3.00         1960      5000     1.0
# 4       510000.0         3       2.00         1680      8080     1.0
# 5      1230000.0         4       4.50         5420    101930     1.0
# 6       257500.0         3       2.25         1715      6819     2.0
# ...          ...       ...        ...          ...       ...     ...
# 21605   610685.0         4       2.50         2520      6023     2.0
# 21606  1010000.0         4       3.50         3510      7200     2.0
# 21607   475000.0         3       2.50         1310      1294     2.0
# 21609   400000.0         4       2.50         2310      5813     2.0
# 21611   400000.0         3       2.50         1600      2388     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
df.query("bedrooms>=3 and bathrooms>=2 or floors<=2")
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
df['price'].max()
# Out:
# 7700000.0

# %%
df['price'].min()
# Out:
# 75000.0

# %%
new= df.query("bedrooms>3 and bathrooms>=2 or floors<=2")

# %%
new['price'].max()
# Out:
# 7700000.0

# %%
#new[new['price'] == new['price'].max()] in pandas
#This filters the row(s) with the highest price in a pandas DataFrame named new.
#new['price'] == new['price'].max() → Creates a boolean mask where only the rows with the highest price are True.
new[new['price']==new['price'].max()]
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7252  7700000.0         6        8.0        12050     27600     2.5
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 7252           0     3          4     13        8570           3480      1910
#
#       yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 7252          1987    98102  47.6298 -122.323           3940        8800

# %%
df['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33])

# %%
#groupby
df.groupby(['bathrooms','bedrooms'])['price'].max()
# Out:
# bathrooms  bedrooms
# 0.00       0           1300000.0
#            1            484000.0
# 0.50       1            255000.0
#            2            273000.0
#            4            312500.0
#                          ...
# 6.75       7            800000.0
# 7.50       9            450000.0
# 7.75       6           6890000.0
# 8.00       6           7700000.0
#            7           2280000.0
# Name: price, Length: 144, dtype: float64

# %%
import pandas as pd
df1 = pd.read_csv("/content/titaanic12.csv")

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df1.shape
# Out:
# (418, 12)

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dummy = df1.drop('PassengerId',axis=1)

# %%
dummy.head()
# Out:
#    Survived  Pclass                                          Name     Sex  \
# 0         0       3                              Kelly, Mr. James    male
# 1         1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2         0       2                     Myles, Mr. Thomas Francis    male
# 3         0       3                              Wirz, Mr. Albert    male
# 4         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
dummy.duplicated().sum()
# Out:
# np.int64(0)

# %%
#df.drop_duplicate(inplace=true)
#Null values
dummy.isnull().any()
# Out:
# Survived    False
# Pclass      False
# Name        False
# Sex         False
# Age          True
# SibSp       False
# Parch       False
# Ticket      False
# Fare         True
# Cabin        True
# Embarked    False
# dtype: bool

# %%
dummy.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %%
round(dummy['Age'].mean(),2)
# Out:
# np.float64(30.27)

# %%
dummy.fillna({'Age':30.27},inplace=True)

# %%
dummy.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %%
dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  418 non-null    int64
#  1   Pclass    418 non-null    int64
#  2   Name      418 non-null    object
#  3   Sex       418 non-null    object
#  4   Age       418 non-null    float64
#  5   SibSp     418 non-null    int64
#  6   Parch     418 non-null    int64
#  7   Ticket    418 non-null    object
#  8   Fare      417 non-null    float64
#  9   Cabin     91 non-null     object
#  10  Embarked  418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
dummy['Cabin'].value_counts()
# Out:
# Cabin
# B57 B59 B63 B66    3
# B45                2
# C23 C25 C27        2
# C78                2
# C31                2
#                   ..
# B41                1
# C7                 1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 76, dtype: int64

# %%
dummy=dummy.drop('Cabin',axis=1)

# %%
dummy
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                              Kelly, Mr. James    male
# 1           1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           0       2                     Myles, Mr. Thomas Francis    male
# 3           0       3                              Wirz, Mr. Albert    male
# 4           1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..        ...     ...                                           ...     ...
# 413         0       3                            Spector, Mr. Woolf    male
# 414         1       1                  Oliva y Ocana, Dona. Fermina  female
# 415         0       3                  Saether, Mr. Simon Sivertsen    male
# 416         0       3                           Ware, Mr. Frederick    male
# 417         0       3                      Peter, Master. Michael J    male
#
# ...

# %%
#dummy.dropna(inplace=True)

# %%
dummy
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                              Kelly, Mr. James    male
# 1           1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           0       2                     Myles, Mr. Thomas Francis    male
# 3           0       3                              Wirz, Mr. Albert    male
# 4           1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..        ...     ...                                           ...     ...
# 413         0       3                            Spector, Mr. Woolf    male
# 414         1       1                  Oliva y Ocana, Dona. Fermina  female
# 415         0       3                  Saether, Mr. Simon Sivertsen    male
# 416         0       3                           Ware, Mr. Frederick    male
# 417         0       3                      Peter, Master. Michael J    male
#
# ...

# %%
dummy.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    30.271974
# male      30.158038
# Name: Age, dtype: float64

# %%
dummy.groupby('Sex')['Age'].min()
# Out:
# Sex
# female    0.17
# male      0.33
# Name: Age, dtype: float64

# %%
dummy.groupby(['Sex','Embarked'])['Age'].count()
# Out:
# Sex     Embarked
# female  C            40
#         Q            24
#         S            88
# male    C            62
#         Q            22
#         S           181
# Name: Age, dtype: int64

# %%
#pivot table
dummy.pivot_table(index='Embarked',columns='Sex',values='Age',aggfunc=['mean','count','max','min'])
# Out:
#                mean             count         max          min
# Sex          female       male female male female  male female   male
# Embarked
# C         35.545250  32.775645     40   62   64.0  64.0   1.00   6.00
# Q         28.447500  31.306364     24   22   37.0  62.0  17.00  10.00
# S         28.372614  29.121823     88  181   76.0  67.0   0.17   0.33

# %%
dummy.head()
# Out:
#    Survived  Pclass                                          Name     Sex  \
# 0         0       3                              Kelly, Mr. James    male
# 1         1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2         0       2                     Myles, Mr. Thomas Francis    male
# 3         0       3                              Wirz, Mr. Albert    male
# 4         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked
# 0  34.5      0      0   330911   7.8292        Q
# 1  47.0      1      0   363272   7.0000        S
# 2  62.0      0      0   240276   9.6875        Q
# 3  27.0      0      0   315154   8.6625        S
# 4  22.0      1      1  3101298  12.2875        S

# %%
dummy.pivot_table(index=['Pclass','Sex'],values='Fare',aggfunc=['count','sum'])
# Out:
#               count        sum
#                Fare       Fare
# Pclass Sex
# 1      female    50  5779.5584
#        male      57  4308.4334
# 2      female    30   793.1625
#        male      63  1271.6332
# 3      female    72   988.9293
#        male     145  1714.8208
